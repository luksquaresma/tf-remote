# %%
import diagrams as d

# %%
from diagrams import Cluster, Diagram, Edge
from diagrams.programming.flowchart import *
from diagrams.oci.governance import Groups
# from diagrams.onprem.client import *
# from diagrams.onprem.compute import *
# from diagrams.generic.compute import *
# from diagrams.oci.monitoring import *
from diagrams.c4 import SystemBoundary



graph_attr = {
    "dpi":"200",
    # "size":"2000000",
    # "dim":"10",
    "beautify":"true",
    # "fontsize": "45",
    "fontcolor": "black",
    # "pad":"0.02",
    # "compound":"true",
    # "colorscheme":"accent8",
    # "smoothType":"graph_dist",
    # "Damping":"0.1",
    # "layout": "neato",
    # "mode": "ipsec", # major KK sgd hier ipsep
    # "model":"shortpath", # shortpath circuit subset
    # "overlap":"prism0", # scalexy compress
    # "pack":"true",
    # "packMode":"graph",
    "maxiter":"1000000",
    # "sep":"10"
    "splines":"true"
}

node_attr = {
    # "pad":"0",
    # "color":"black",
    # "fontcolor": "black",
    # "colorscheme":"accent8",
}

edge_attr = {
    # "pad":"0",
    # "color":"black",
    # "fontcolor": "black",
    # "colorscheme":"accent8",
}

with Diagram(show=False, graph_attr=graph_attr, edge_attr=edge_attr, # direction="TB"
    # outformat="png", filename="Architecture"
    ) as diag:

    user = Groups("User")

    with SystemBoundary("Client"):
        
        status_checker = PredefinedProcess("Status\nchecker")
        
        get_results = PredefinedProcess("Result\ngetter")
        
        with Cluster("Modeling input"):
            input = [
                ManualInput("Search\nmetaparameters"),
                ManualInput("Metamodel\narchitecture\nparameters"),
                ManualInput("Raw data"),
            ]
        
        model_desc = PredefinedProcess("Metamodel\ndescriptor")
        
        with Cluster("Metamodel\narchitecture"):
            h5_files = MultipleDocuments("Model\nfiles (.h5)")
            train_param = MultipleDocuments("Training\nparameters")
            meta_models = [
                train_param,
                h5_files,
                MultipleDocuments("Processed\ndata"),
            ]
        
        job_maker = Preparation("Job\nmaker")

        with Cluster("Metamodel\ntraining jobs"):
            meta_data = MultipleDocuments("Data\ncollections")
            meta_jobs = InternalStorage("Trainning\njobs")

        job_sender = PredefinedProcess("Job\nsender")


    with SystemBoundary("Server"):      
        job_reciever = Preparation("Job\nreciever")
        status_reporter = PredefinedProcess("Status\nreporter")
        result_reporter = PredefinedProcess("Result\nreporter")

        with Cluster("Data"):
            server_data_index = Database("Data\nindex")
            server_data = MultipleDocuments("Job\ndata")

        with Cluster("Compute"):
            job_compute = PredefinedProcess("Job\ncompute")
            job_queue = InternalStorage("Job\nqueue")
            

    # Client side connections
    # user>>input>>model_desc>>meta_models>>job_maker>>[meta_data,meta_jobs]>>job_sender
    # user>>status_checker>>api>>status_reporter>>job_queue

    # Server side connections
    # server_data - server_data_index

    user>>input>>model_desc>>meta_models>>job_maker>>[meta_data,meta_jobs]\
        >>job_sender>>job_reciever>>[server_data_index,server_data]>>job_queue\
            >>job_compute>>server_data

    user - status_checker - status_reporter<<job_queue
    
    user - get_results - result_reporter<<server_data
    
    
    # get_results
    # api>>job_reciever>>[server_data_index,server_data]>>job_queue>>job_compute>>server_data
    # api<<status_reporter<<job_queue
    # api<<result_reporter<<server_data
    # # [server_data,server_data_index]>>job_queue>>job_compute>>[server_data]




# req_data_send = InputOutput("Send data\nrequest")
    # req_status = InputOutput("Status\nrequest")
    # req_data_get = InputOutput("Get data\nrequest")
    # req_job = InputOutput("Manage job\nrequest")

    # Server side connections
    # user >> req_data_get >> api
    # user >> req_status >> api << job_queue
    # meta_data >> req_data_send >> api >> server_data_index #, server_data]
    # meta_jobs >> req_job >> api >> server_db >> job_queue >> job_compute
    # server_data >> [api, job_compute]

# %%
from diagrams import Cluster, Diagram, Edge
from diagrams.programming.flowchart import *
from diagrams.onprem.client import *
from diagrams.onprem.compute import *
from diagrams.generic.compute import *
from diagrams.oci.monitoring import *
from diagrams.c4 import SystemBoundary



graph_attr = {
    # "dpi":"400",
    # "size":"20",
    # "dim":"10",
    # "beautify":"true",
    # "fontsize": "45",
    # "fontcolor": "black",
    # "pad":"0.02",
    # "colorscheme":"accent8",
    # "smoothType":"graph_dist",
    "layout": "dot"
}

node_attr = {
    # "pad":"0",
    # "color":"black",
    # "fontcolor": "black",
    # "colorscheme":"accent8",
}

edge_attr = {
    # "pad":"0",
    # "color":"black",
    # "fontcolor": "black",
    # "colorscheme":"accent8",
}

with Diagram(show=False, graph_attr=graph_attr, edge_attr=edge_attr, # direction="TB"
    # outformat="png", filename="Architecture"
    ) as diag:


    # Client side
    user = User("User")

    with SystemBoundary("Client") as sb:
        with Cluster("Input"):
            input = [
                ManualInput("Search\nmetaparameters"),
                ManualInput("Metamodel\narchitecture\nparameters"),
                ManualInput("Raw data"),
            ]
        
        model_desc = PredefinedProcess("Metamodel\ndescriptor")
        
        with Cluster("Metamodel\narchitecture"):
            h5_files = MultipleDocuments("Model\nfiles (.h5)")
            train_param = MultipleDocuments("Training\nparameters")
            meta_models = [
                train_param,
                h5_files,
                MultipleDocuments("Processed\ndata"),
            ]
        
        job_maker = Preparation("Job\nmaker")

        with Cluster("Metamodel\ntraining jobs") as inter:
            meta_data = MultipleDocuments("Data\ncollections")
            meta_jobs = InternalStorage("Trainning\njobs")

    user >> input >> model_desc >> meta_models >> job_maker >> [meta_data, meta_jobs]

    # Interface
    api_data = Collate("Send data\nAPI Endpoint")
    api_job = Collate("Send jobs\nAPI Endpoint")
    api_status = Collate("Status\nAPI Endpoint")

    sb >> Edge(label="parse") >> api_data

    # Edge(label="parse")
    # [meta_data, meta_jobs] - api_job
    # [meta_data, meta_jobs] - api_status






    # with SystemBoundary("Server"):      
    #     with Cluster("Data flux"):
    #         server_data = MultipleDocuments("Job data")
    #         server_data_index = Database("Data index")
    #         server_data_index - server_data

    #     with Cluster("Job flux"):
    #         server_compute = PredefinedProcess("Job compute")
    #         server_queue = InternalStorage("Job queue")
    #         server_db = Database("Server job DB")
    
    

    # >> [api_data, api_job, api_status]

    # req_data_send = InputOutput("Send data\nrequest")
    # req_status = InputOutput("Status\nrequest")
    # req_data_get = InputOutput("Get data\nrequest")
    # req_job = InputOutput("Manage job\nrequest")

    # Server side connections
    # user >> req_data_get >> api
    # user >> req_status >> api_status - server_queue
    # meta_data >> req_data_send >> api_data >> server_data_index #, server_data]
    # meta_jobs >> req_job >> api >> server_db >> server_queue >> server_compute
    # server_data >> [api, server_compute]

# %%
from diagrams import Diagram, Cluster
from diagrams.oci.compute import Functions
from diagrams.oci.connectivity import Backbone
from diagrams.oci.database import DMS
from diagrams.oci.governance import Audit, Groups
from diagrams.oci.storage import FileStorage
from diagrams.c4 import SystemBoundary

# IotAnalyticsDataSet


graph_attr = {
    "dpi":"400",
    "size":"20",
    "dim":"1",
    "beautify":"true",
    # "fontsize": "45",
    "fontcolor": "black",
    "pad":"0.05",
    # "colorscheme":"accent8",
    "smoothType":"graph_dist",
    # "layout": "dot"
    "bgcolor": "transparent"
}

node_attr = {
    "pad":"200",
    # "color":"black",
    "fontcolor": "black",
    "bgcolor": "transparent"
}

edge_attr = {
    "pad":"0",
    # "color":"black",
    "fontcolor": "black",
    "bgcolor": "transparent"
}

with Diagram(show=False, graph_attr=graph_attr, edge_attr=edge_attr, node_attr=node_attr# direction="TB"
    # outformat="png", filename="Architecture"
    ) as diag:
    user = Groups("End user")

    with SystemBoundary("Client"):
        c_ui = Client("UI")
        
        with Cluster("Input"):
            c_input = [
                FileStorage("Raw\ndata"),
                Audit("Search\nmetaparameters"),
                Audit("Metamodel\narchitecture\nparameters"),
            ]
        
        c_metajob_maker = Functions("Metamodel\njob\nmaker")
        
        with Cluster("Metamodel\narchitecture"):
            c_metajobs = [
                FileStorage("Processed\ndata"),
                FileStorage("Model\nfiles (.h5)"),
                Audit("Training\nparameters"),
            ]
        
        c_job_sender = Functions("Job\nsender")

        user>>c_ui>>c_input>>c_metajob_maker>>c_metajobs>>c_job_sender

    
    with SystemBoundary("Server"):
        s_api_job = Backbone("Job\nAPI\nendpoint")
        s_api_data = Backbone("Job\nAPI\nendpoint")
        
        s_model_data = FileStorage("Processed\ndata"),
        s_model_files = FileStorage("Model\nfiles (.h5)"),
        
        
        s_api_status = Backbone("Job\nAPI\nendpoint")
        

    c_job_sender>>s_api_job

   
        # [c_raw_data, c_model_arch_par]
    
        # c_job_maker >> [c_proc_data, c_h5_files, c_train_param]
        # >>c_model_desc
        # user>>c_ui>>c_input>>model_desc>>meta_models
# diag

# %%
from diagrams import Diagram, Cluster
from diagrams.c4 import Person, Container, Database, System, SystemBoundary, Relationship
# IotAnalyticsDataSet


graph_attr = {
    "dpi":"400",
    "size":"20",
    "dim":"1",
    "beautify":"true",
    # "fontsize": "45",
    "fontcolor": "black",
    "pad":"0.05",
    # "colorscheme":"accent8",
    "smoothType":"graph_dist",
    # "layout": "dot"
    "bgcolor": "transparent"
}

node_attr = {
    # "fontsize": "45",
    "pad":"200",
    # "color":"black",
    "fontcolor": "black",
    "bgcolor": "transparent"
}

edge_attr = {
    "pad":"0",
    # "color":"black",
    "fontcolor": "black",
    "bgcolor": "transparent"
}

with Diagram(show=False, graph_attr=graph_attr, edge_attr=edge_attr, node_attr=node_attr# direction="TB"
    # outformat="png", filename="Architecture"
    ) as diag:
    user = Person("End user")

    with SystemBoundary("Client"):
        c_ui = System("UI", description="Local machine")
        
        with Cluster("Input"):
            c_input = [
                Database("Raw data"),
                Container("Search metaparameters", technology="Java and Spring MVC",),
                Container("Metamodel architecture parameters"),
            ]
        
        c_metajob_maker = System("Metamodel job maker")
        
        with Cluster("Metamodel architecture"):
            c_metajobs = [
                Database("Processed data"),
                Database("Model files (.h5)"),
                Container("Training parameters"),
            ]
        
        c_job_sender = System("Job sender")

        user>>c_ui>>c_input>>c_metajob_maker>>c_metajobs>>c_job_sender

    
    with SystemBoundary("Server"):
        s_api_job = System("Job API endpoint")
        s_api_data = System("Job API endpoint")
        
        s_model_data = Database("Processed data"),
        s_model_files = Database("Model files (.h5)"),
        
        
        s_api_status = System("Job API endpoint")
        

    c_job_sender>>s_api_job

   
        # [c_raw_data, c_model_arch_par]
    
        # c_job_maker >> [c_proc_data, c_h5_files, c_train_param]
        # >>c_model_desc
        # user>>c_ui>>c_input>>model_desc>>meta_models
# diag
